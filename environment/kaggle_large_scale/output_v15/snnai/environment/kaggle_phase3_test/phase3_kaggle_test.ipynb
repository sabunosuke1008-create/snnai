# %% [markdown]
# # SNNAI Phase3 Kaggle CPU 動作確認
#
# GitHub リポジトリを clone し、Phase3 のミツバチモジュールのテストを Kaggle CPU 上で実行する。

# %%
# Install snntorch and clone the latest repo, then run Phase3 test in the repo directory
# !pip install snntorch==0.9.4 --quiet
# !rm -rf snnai && git clone https://github.com/sabunosuke1008-create/snnai.git
# !ls snnai/tests/
# !cd snnai && python -m pytest tests/test_honeybee_learning.py -v -s --tb=short
